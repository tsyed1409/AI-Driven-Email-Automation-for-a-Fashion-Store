# %% [markdown]
# # AI-Driven Email Automation for a Fashion Store
#
# Portfolio notebook demonstrating an LLM workflow for classifying retail emails, extracting order details, retrieving relevant product information with FAISS, and generating customer responses.
#
# **Security note:** API credentials are read from environment variables and are never stored in this notebook.

# %% [markdown]
# ## 1. Setup

# %%
import os
import json
from openai import OpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

if not os.getenv('OPENAI_API_KEY'):
    raise EnvironmentError('Set OPENAI_API_KEY before running this notebook.')

client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %% [markdown]
# ## 2. Example data
#
# The original assessment used a fashion-store product catalogue and customer emails. The small examples below keep the portfolio version self-contained.

# %%
products = [
    {'product_id': 'P1001', 'name': 'Black Classic T-Shirt', 'stock': 12, 'description': 'Cotton crew-neck T-shirt'},
    {'product_id': 'P1002', 'name': 'Blue Denim Jacket', 'stock': 4, 'description': 'Mid-weight denim jacket'},
    {'product_id': 'P1003', 'name': 'White Trainers', 'stock': 0, 'description': 'Low-top casual trainers'},
]

sample_emails = [
    'Can I order two P1001 shirts please?',
    'Do you have a blue jacket suitable for autumn?',
]

# %% [markdown]
# ## 3. LLM classification and structured extraction

# %%
def classify_email(email_text: str) -> dict:
    prompt = f'''Classify the customer email as either order_request or product_inquiry.
If it is an order request, also extract product_id and quantity when present.
Return JSON only with keys: category, product_id, quantity.
Email: {email_text}'''

    response = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=[{'role': 'user', 'content': prompt}],
        response_format={'type': 'json_object'},
        temperature=0,
    )
    return json.loads(response.choices[0].message.content)

# %% [markdown]
# ## 4. Product retrieval with embeddings and FAISS

# %%
embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
product_texts = [
    f"{p['product_id']} | {p['name']} | {p['description']} | stock={p['stock']}"
    for p in products
]
vector_store = FAISS.from_texts(product_texts, embeddings)

def retrieve_products(query: str, k: int = 3):
    return vector_store.similarity_search(query, k=k)

# %% [markdown]
# ## 5. Stock check and response generation

# %%
def find_product(product_id: str):
    return next((p for p in products if p['product_id'] == product_id), None)

def process_order(product_id: str, quantity: int) -> dict:
    product = find_product(product_id)
    if not product:
        return {'status': 'not_found', 'product_id': product_id}
    if product['stock'] < quantity:
        return {'status': 'insufficient_stock', 'product_id': product_id, 'available': product['stock']}
    product['stock'] -= quantity
    return {'status': 'created', 'product_id': product_id, 'quantity': quantity}

def generate_customer_reply(email_text: str, context: str) -> str:
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=[
            {'role': 'system', 'content': 'You are a concise and professional fashion-store customer service assistant.'},
            {'role': 'user', 'content': f'Customer email: {email_text}\nContext: {context}\nDraft a helpful reply.'},
        ],
        temperature=0.2,
    )
    return response.choices[0].message.content

# %% [markdown]
# ## 6. Production considerations
#
# A production version would add schema validation, retry/error handling, observability, human review for low-confidence or high-impact cases, authenticated email and inventory integrations, secrets management, and automated evaluation.
